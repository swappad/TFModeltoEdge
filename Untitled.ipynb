# %%
from pynq_dpu import DpuOverlay
from dnndk import n2cube
overlay = DpuOverlay("./dpu.bit")

# %%
# !dexplorer -w
# Out:
# [DPU IP Spec]
# IP  Timestamp            : 2020-03-26 13:30:00
# DPU Core Count           : 1
#
# [DPU Core Configuration List]
# DPU Core                 : #0
# DPU Enabled              : Yes
# DPU Arch                 : B1600
# DPU Target Version       : v1.4.1
# DPU Freqency             : 300 MHz
# Ram Usage                : Low
# DepthwiseConv            : Enabled
# DepthwiseConv+Relu6      : Enabled
# Conv+Leakyrelu           : Enabled
# Conv+Relu6               : Enabled
# Channel Augmentation     : Disabled
# Average Pool             : Enabled

# %%
overlay.load_model("./dpu_Unet.elf")

# %%
KERNEL_NAME = "Unet"
KERNEL_CONV_INPUT = "block1_conv1_convolution"
KERNEL_OUTPUT = "conv2d_13_convolution"

# %%
n2cube.dpuOpen()
kernel = n2cube.dpuLoadKernel(KERNEL_NAME)
task = n2cube.dpuCreateTask(kernel, 0)

# %%
input_len = n2cube.dpuGetInputTensorSize(task, KERNEL_CONV_INPUT)
output_len = n2cube.dpuGetOutputTensorSize(task, KERNEL_OUTPUT)
conf = n2cube.dpuGetOutputTensorAddress(task, KERNEL_OUTPUT)
output_scale = n2cube.dpuGetOutputTensorScale(task, KERNEL_OUTPUT)
print(input_len, output_len, conf, output_scale)
# Out:
# 393216 524288 <dnndk.n2cube.LP_c_byte object at 0x7f9a4e5488> 0.0625

# %%
n2cube.dpuGetOutputTensorChannel(task, KERNEL_OUTPUT)
# Out:
# 4

# %%
import numpy as np
import os
from time import time
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %%
def result_map_to_img(res_map):
    img = np.zeros((256, 512, 3), dtype=np.uint8)
    res = np.squeeze(res_map)
  
    argmax_idx = np.argmax(res, axis=2)
  
    # For np.where calculation.
    person = (argmax_idx == 1)
    car = (argmax_idx == 2)
    road = (argmax_idx == 3)
  
    img[:, :, 2] = np.where(person, 255, 0)
    img[:, :, 1] = np.where(car, 255, 0)
    img[:, :, 0] = np.where(road, 255, 0)
  
    return img

# %%
image = cv2.imread("/home/xilinx/jupyter_notebooks/own/leftImg8bit/train/aachen/aachen_000008_000019_leftImg8bit.png")

try:
    image_small = cv2.resize(image, (512, 256))
    img = cv2.cvtColor(image_small, cv2.COLOR_BGR2RGB)
    #image_small = image_small.transpose((2,0,1)) 
    imag = img / 127.5 - 1
    #image_small = np.expand_dims(image_small, 0)
    image_data = np.array(img, dtype=np.float32)
    plt.imshow(image)
except cv2.error as e:
    print('Invald frame!')
    print(e)
image_data.shape
# Out:
# (256, 512, 3)

# %%
calib_img_path = "./leftImg8bit/train/"
calib_batch_size = 1
## images for evaluation
paths = []
for (path, dirname, files) in sorted(os.walk(calib_img_path)):
    for filename in sorted(files):
        if filename.endswith(('.jpg', '.png')):
            paths.append(os.path.join(path, filename))
images = []
for index in range(0, calib_batch_size):
    #print("Path: " + paths[(iter * calib_batch_size + index) % len(paths)])
    img_raw = cv2.imread(paths[(100 * calib_batch_size + index) % len(paths)], 1)
    try:
        img_scaled = cv2.resize(img_raw,(512, 256))
        img = cv2.cvtColor(img_scaled, cv2.COLOR_BGR2RGB)
        img = img.astype(np.float32) / 127.5 - 1
        images.append(img.astype(np.float32))
        plt.imshow(img_scaled)
    except cv2.error as e:
            print('Invalid frame!')
            print(e)
image_data = np.expand_dims(images[0], 0)
image_data.shape
# Out:
# (1, 256, 512, 3)

# %%
n2cube.dpuSetInputTensorInHWCFP32(task, KERNEL_CONV_INPUT, image_data, input_len)
n2cube.dpuRunTask(task)
image_out = n2cube.dpuGetOutputTensorInHWCFP32(task, KERNEL_OUTPUT, output_len)

# %%
classes = np.array(image_out, dtype=np.float32)
classes = np.reshape(classes, (1, 256, 512, 4))
result = result_map_to_img(classes)
plt.imshow(result)

# %%
classes
# Out:
# array([[[[ 1.375 , -1.75  , -1.625 , -0.8125],
#          [ 1.8125, -2.9375, -1.9375, -2.25  ],
#          [ 2.    , -2.8125, -2.375 , -3.125 ],
#          ...,
#          [ 1.9375, -2.5   , -1.9375, -0.875 ],
#          [ 1.625 , -2.5625, -1.75  , -0.1875],
#          [ 1.25  , -1.9375, -0.8125, -0.0625]],
#
#         [[ 2.    , -2.5625, -1.5625, -1.875 ],
#          [ 2.4375, -3.625 , -1.5   , -2.875 ],
#          [ 3.0625, -4.125 , -2.1875, -4.25  ],
#          ...,
#          [ 3.4375, -3.3125, -2.625 , -1.    ],
#          [ 3.1875, -3.5   , -2.625 , -0.5   ],
#          [ 2.375 , -2.8125, -1.5625,  0.0625]],
#
#         [[ 2.5625, -2.875 , -2.    , -2.1875],
#          [ 2.75  , -3.125 , -1.9375, -3.9375],
#          [ 3.125 , -3.125 , -2.5625, -5.625 ],
#          ...,
#          [ 2.625 , -3.5   , -3.125 , -1.75  ],
#          [ 2.4375, -3.375 , -2.875 , -0.9375],
#          [ 2.    , -2.4375, -1.875 , -0.3125]],
#
#         ...,
#
#         [[ 0.625 , -1.625 , -1.375 ,  1.    ],
#          [ 1.    , -3.1875, -1.8125,  2.125 ],
#          [ 0.625 , -3.    , -1.875 ,  2.625 ],
#          ...,
#          [ 0.9375, -2.0625, -1.0625, -1.    ],
#          [ 1.125 , -2.125 , -1.5   , -1.9375],
#          [ 1.25  , -1.4375, -0.875 , -0.4375]],
#
#         [[ 0.5   , -1.8125, -1.5   ,  0.8125],
#          [ 0.6875, -3.1875, -1.875 ,  1.75  ],
#          [ 0.75  , -3.125 , -1.5625,  2.3125],
#          ...,
#          [ 1.0625, -2.    , -0.9375, -1.0625],
#          [ 1.375 , -1.875 , -1.375 , -1.3125],
#          [ 1.1875, -1.5   , -0.9375, -0.1875]],
#
#         [[ 0.4375, -1.    , -1.    ,  0.4375],
#          [ 1.    , -2.    , -1.625 ,  1.0625],
#          [ 1.0625, -2.0625, -1.3125,  1.5625],
#          ...,
#          [ 0.9375, -1.4375, -0.9375, -0.0625],
#          [ 1.3125, -1.6875, -1.25  , -0.4375],
#          [ 1.25  , -1.5   , -0.625 ,  0.1875]]]], dtype=float32)

# %%
n2cube.dpuDestroyTask(task)
n2cube.dpuDestroyKernel(kernel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a62eaa49b611> in <module>()
# ----> 1 n2cube.dpuDestroyTask(task)
#       2 n2cube.dpuDestroyKernel(kernel)
#
# NameError: name 'n2cube' is not defined
